# %%
import os
import requests

# API anahtarınızı doğrudan buraya girin
apiKey = 'dcbe55c1e3134568a5824acb8fc1ca1a'  # Buraya kendi API anahtarınızı ekleyin
baseUrl = "http://api.openweathermap.org/data/2.5/"

class HavaDurumuAlici:
    def __init__(self, apiKey):
        self.apiKey = apiKey

    def havaDurumuGetir(self, sehir):
        try:
            url = f"{baseUrl}weather?q={sehir}&appid={self.apiKey}&units=metric&lang=tr"
            cevap = requests.get(url)
            veri = cevap.json()

            if cevap.status_code == 200:
                return veri
            else:
                print(f"{sehir} şehri bulunamadı veya başka bir hata oluştu. Durum kodu: {cevap.status_code}.")
                return None
        except Exception as e:
            print(f"Hata: {e}")
            return None

    def tahminGetir(self, sehir):
        try:
            url = f"{baseUrl}forecast?q={sehir}&appid={self.apiKey}&units=metric&lang=tr"
            cevap = requests.get(url)
            veri = cevap.json()

            if cevap.status_code == 200:
                return veri
            else:
                print(f"{sehir} şehri bulunamadı veya başka bir hata oluştu. Durum kodu: {cevap.status_code}.")
                return None
        except Exception as e:
            print(f"Hata: {e}")
            return None

    def havaDurumuBilgileriniYazdir(self, sehir):
        havaDurumuVerisi = self.havaDurumuGetir(sehir)

        if havaDurumuVerisi:
            print(f"\n{sehir} için hava durumu:")
            print(f"Sıcaklık: {havaDurumuVerisi['main']['temp']}°C")
            print(f"Hissedilen Sıcaklık: {havaDurumuVerisi['main']['feels_like']}°C")
            print(f"Nem: {havaDurumuVerisi['main']['humidity']}%")
            print(f"Rüzgar Hızı: {havaDurumuVerisi['wind']['speed']} m/s")
            print(f"Rüzgar Yönü: {havaDurumuVerisi['wind']['deg']}°")

            if 'weather' in havaDurumuVerisi and len(havaDurumuVerisi['weather']) > 0:
                aciklama = havaDurumuVerisi['weather'][0]['description']
                print(f"Hava Durumu: {aciklama.capitalize()}")
            else:
                print("Hava durumu bilgisi bulunamadı.")
    
    def farkliZamanDilimlerindeHavaDurumu(self, sehir):
        tahminVerisi = self.tahminGetir(sehir)
        if tahminVerisi:
            print(f"\n{sehir} için farklı zaman dilimlerinde hava durumu:")
            for giris in tahminVerisi['list']:
                tarih = giris['dt_txt']
                sicaklik = giris['main']['temp']
                aciklama = giris['weather'][0]['description']
                print(f"Tarih: {tarih} - Sıcaklık: {sicaklik}°C - Hava Durumu: {aciklama.capitalize()}")

def ana():
    print("Hava Durumu Uygulamasına Hoşgeldiniz!")
    print("Bu program, girdiğiniz şehir için hava durumu bilgilerini, farklı zaman dilimlerinde hava durumunu ve hava durumu uyarılarını sağlar.")
    print("Programdan çıkmak için 'çık' yazabilirsiniz.\n")
    
    alici = HavaDurumuAlici(apiKey)
    
    while True:
        sehir = input("Şehir adını girin (çıkmak için 'çık' yazın): ").strip()
        if sehir.lower() == 'çık':
            print("Programdan çıkılıyor...")
            break
        if not sehir:
            print("Geçersiz şehir adı, lütfen tekrar deneyin.")
            continue

        alici.havaDurumuBilgileriniYazdir(sehir)
        alici.farkliZamanDilimlerindeHavaDurumu(sehir)

if __name__ == "__main__":
    ana()
# Out:
# Hava Durumu Uygulamasına Hoşgeldiniz!
# Bu program, girdiğiniz şehir için hava durumu bilgilerini, farklı zaman dilimlerinde hava durumunu ve hava durumu uyarılarını sağlar.
# Programdan çıkmak için 'çık' yazabilirsiniz.
#
#
# Ankara için hava durumu:
# Sıcaklık: 29.3°C
# Hissedilen Sıcaklık: 27.82°C
# Nem: 24%
# Rüzgar Hızı: 3.6 m/s
# Rüzgar Yönü: 70°
# Hava Durumu: Açık
#
# Ankara için farklı zaman dilimlerinde hava durumu:
# Tarih: 2024-08-14 21:00:00 - Sıcaklık: 27.45°C - Hava Durumu: Açık
# Tarih: 2024-08-15 00:00:00 - Sıcaklık: 23.47°C - Hava Durumu: Açık
# Tarih: 2024-08-15 03:00:00 - Sıcaklık: 18.64°C - Hava Durumu: Açık
# Tarih: 2024-08-15 06:00:00 - Sıcaklık: 23.64°C - Hava Durumu: Açık
# Tarih: 2024-08-15 09:00:00 - Sıcaklık: 29.47°C - Hava Durumu: Açık
# Tarih: 2024-08-15 12:00:00 - Sıcaklık: 32.57°C - Hava Durumu: Açık
# Tarih: 2024-08-15 15:00:00 - Sıcaklık: 33.18°C - Hava Durumu: Açık
# Tarih: 2024-08-15 18:00:00 - Sıcaklık: 26.65°C - Hava Durumu: Açık
# Tarih: 2024-08-15 21:00:00 - Sıcaklık: 22.84°C - Hava Durumu: Açık
# Tarih: 2024-08-16 00:00:00 - Sıcaklık: 20.34°C - Hava Durumu: Açık
# Tarih: 2024-08-16 03:00:00 - Sıcaklık: 18.44°C - Hava Durumu: Açık
# Tarih: 2024-08-16 06:00:00 - Sıcaklık: 22.75°C - Hava Durumu: Açık
# Tarih: 2024-08-16 09:00:00 - Sıcaklık: 27.89°C - Hava Durumu: Açık
# Tarih: 2024-08-16 12:00:00 - Sıcaklık: 29.92°C - Hava Durumu: Açık
# Tarih: 2024-08-16 15:00:00 - Sıcaklık: 29.19°C - Hava Durumu: Açık
# Tarih: 2024-08-16 18:00:00 - Sıcaklık: 23.74°C - Hava Durumu: Açık
# Tarih: 2024-08-16 21:00:00 - Sıcaklık: 19.72°C - Hava Durumu: Açık
# Tarih: 2024-08-17 00:00:00 - Sıcaklık: 16.76°C - Hava Durumu: Açık
# Tarih: 2024-08-17 03:00:00 - Sıcaklık: 14.73°C - Hava Durumu: Açık
# Tarih: 2024-08-17 06:00:00 - Sıcaklık: 20.58°C - Hava Durumu: Açık
# Tarih: 2024-08-17 09:00:00 - Sıcaklık: 26.54°C - Hava Durumu: Açık
# Tarih: 2024-08-17 12:00:00 - Sıcaklık: 29.04°C - Hava Durumu: Açık
# Tarih: 2024-08-17 15:00:00 - Sıcaklık: 29.21°C - Hava Durumu: Açık
# Tarih: 2024-08-17 18:00:00 - Sıcaklık: 23.72°C - Hava Durumu: Açık
# Tarih: 2024-08-17 21:00:00 - Sıcaklık: 19.99°C - Hava Durumu: Açık
# Tarih: 2024-08-18 00:00:00 - Sıcaklık: 17.59°C - Hava Durumu: Açık
# Tarih: 2024-08-18 03:00:00 - Sıcaklık: 15.71°C - Hava Durumu: Açık
# Tarih: 2024-08-18 06:00:00 - Sıcaklık: 21.98°C - Hava Durumu: Açık
# Tarih: 2024-08-18 09:00:00 - Sıcaklık: 28.46°C - Hava Durumu: Açık
# Tarih: 2024-08-18 12:00:00 - Sıcaklık: 31.67°C - Hava Durumu: Açık
# Tarih: 2024-08-18 15:00:00 - Sıcaklık: 31.74°C - Hava Durumu: Açık
# Tarih: 2024-08-18 18:00:00 - Sıcaklık: 25.49°C - Hava Durumu: Açık
# Tarih: 2024-08-18 21:00:00 - Sıcaklık: 22.5°C - Hava Durumu: Açık
# Tarih: 2024-08-19 00:00:00 - Sıcaklık: 20.86°C - Hava Durumu: Açık
# Tarih: 2024-08-19 03:00:00 - Sıcaklık: 19.35°C - Hava Durumu: Açık
# Tarih: 2024-08-19 06:00:00 - Sıcaklık: 27.6°C - Hava Durumu: Açık
# Tarih: 2024-08-19 09:00:00 - Sıcaklık: 32.31°C - Hava Durumu: Açık
# Tarih: 2024-08-19 12:00:00 - Sıcaklık: 34.63°C - Hava Durumu: Açık
# Tarih: 2024-08-19 15:00:00 - Sıcaklık: 34.19°C - Hava Durumu: Açık
# Tarih: 2024-08-19 18:00:00 - Sıcaklık: 26.57°C - Hava Durumu: Açık
#
# İzmir için hava durumu:
# Sıcaklık: 29.97°C
# Hissedilen Sıcaklık: 30.7°C
# Nem: 48%
# Rüzgar Hızı: 4.63 m/s
# Rüzgar Yönü: 10°
# Hava Durumu: Açık
#
# İzmir için farklı zaman dilimlerinde hava durumu:
# Tarih: 2024-08-14 21:00:00 - Sıcaklık: 29.02°C - Hava Durumu: Açık
# Tarih: 2024-08-15 00:00:00 - Sıcaklık: 26.87°C - Hava Durumu: Açık
# Tarih: 2024-08-15 03:00:00 - Sıcaklık: 23.56°C - Hava Durumu: Açık
# Tarih: 2024-08-15 06:00:00 - Sıcaklık: 31.1°C - Hava Durumu: Açık
# Tarih: 2024-08-15 09:00:00 - Sıcaklık: 39.99°C - Hava Durumu: Açık
# Tarih: 2024-08-15 12:00:00 - Sıcaklık: 44.33°C - Hava Durumu: Açık
# Tarih: 2024-08-15 15:00:00 - Sıcaklık: 40.26°C - Hava Durumu: Açık
# Tarih: 2024-08-15 18:00:00 - Sıcaklık: 29.38°C - Hava Durumu: Açık
# Tarih: 2024-08-15 21:00:00 - Sıcaklık: 24.16°C - Hava Durumu: Açık
# Tarih: 2024-08-16 00:00:00 - Sıcaklık: 21.42°C - Hava Durumu: Açık
# Tarih: 2024-08-16 03:00:00 - Sıcaklık: 19.42°C - Hava Durumu: Açık
# Tarih: 2024-08-16 06:00:00 - Sıcaklık: 26.94°C - Hava Durumu: Açık
# Tarih: 2024-08-16 09:00:00 - Sıcaklık: 35.48°C - Hava Durumu: Açık
# Tarih: 2024-08-16 12:00:00 - Sıcaklık: 39.79°C - Hava Durumu: Açık
# Tarih: 2024-08-16 15:00:00 - Sıcaklık: 38.53°C - Hava Durumu: Açık
# Tarih: 2024-08-16 18:00:00 - Sıcaklık: 27.41°C - Hava Durumu: Açık
# Tarih: 2024-08-16 21:00:00 - Sıcaklık: 22.57°C - Hava Durumu: Açık
# Tarih: 2024-08-17 00:00:00 - Sıcaklık: 19.93°C - Hava Durumu: Açık
# Tarih: 2024-08-17 03:00:00 - Sıcaklık: 18.28°C - Hava Durumu: Açık
# Tarih: 2024-08-17 06:00:00 - Sıcaklık: 24.9°C - Hava Durumu: Açık
# Tarih: 2024-08-17 09:00:00 - Sıcaklık: 35.31°C - Hava Durumu: Açık
# Tarih: 2024-08-17 12:00:00 - Sıcaklık: 40.44°C - Hava Durumu: Açık
# Tarih: 2024-08-17 15:00:00 - Sıcaklık: 38.1°C - Hava Durumu: Açık
# Tarih: 2024-08-17 18:00:00 - Sıcaklık: 27.08°C - Hava Durumu: Açık
# Tarih: 2024-08-17 21:00:00 - Sıcaklık: 22.4°C - Hava Durumu: Açık
# Tarih: 2024-08-18 00:00:00 - Sıcaklık: 20.39°C - Hava Durumu: Açık
# Tarih: 2024-08-18 03:00:00 - Sıcaklık: 18.59°C - Hava Durumu: Açık
# Tarih: 2024-08-18 06:00:00 - Sıcaklık: 25.45°C - Hava Durumu: Açık
# Tarih: 2024-08-18 09:00:00 - Sıcaklık: 36.06°C - Hava Durumu: Açık
# Tarih: 2024-08-18 12:00:00 - Sıcaklık: 39.28°C - Hava Durumu: Açık
# Tarih: 2024-08-18 15:00:00 - Sıcaklık: 37.47°C - Hava Durumu: Açık
# Tarih: 2024-08-18 18:00:00 - Sıcaklık: 27.55°C - Hava Durumu: Açık
# Tarih: 2024-08-18 21:00:00 - Sıcaklık: 24.48°C - Hava Durumu: Açık
# Tarih: 2024-08-19 00:00:00 - Sıcaklık: 22.93°C - Hava Durumu: Açık
# Tarih: 2024-08-19 03:00:00 - Sıcaklık: 21.99°C - Hava Durumu: Açık
# Tarih: 2024-08-19 06:00:00 - Sıcaklık: 28.98°C - Hava Durumu: Açık
# Tarih: 2024-08-19 09:00:00 - Sıcaklık: 35.94°C - Hava Durumu: Açık
# Tarih: 2024-08-19 12:00:00 - Sıcaklık: 39.06°C - Hava Durumu: Açık
# Tarih: 2024-08-19 15:00:00 - Sıcaklık: 35.82°C - Hava Durumu: Açık
# Tarih: 2024-08-19 18:00:00 - Sıcaklık: 26.85°C - Hava Durumu: Açık
#
# İstanbul için hava durumu:
# Sıcaklık: 27.68°C
# Hissedilen Sıcaklık: 28.18°C
# Nem: 51%
# Rüzgar Hızı: 10.8 m/s
# Rüzgar Yönü: 60°
# Hava Durumu: Açık
#
# İstanbul için farklı zaman dilimlerinde hava durumu:
# Tarih: 2024-08-14 21:00:00 - Sıcaklık: 26.86°C - Hava Durumu: Açık
# Tarih: 2024-08-15 00:00:00 - Sıcaklık: 25.67°C - Hava Durumu: Açık
# Tarih: 2024-08-15 03:00:00 - Sıcaklık: 24.38°C - Hava Durumu: Açık
# Tarih: 2024-08-15 06:00:00 - Sıcaklık: 26.61°C - Hava Durumu: Açık
# Tarih: 2024-08-15 09:00:00 - Sıcaklık: 29.21°C - Hava Durumu: Açık
# Tarih: 2024-08-15 12:00:00 - Sıcaklık: 29.51°C - Hava Durumu: Açık
# Tarih: 2024-08-15 15:00:00 - Sıcaklık: 27.37°C - Hava Durumu: Açık
# Tarih: 2024-08-15 18:00:00 - Sıcaklık: 25.06°C - Hava Durumu: Açık
# Tarih: 2024-08-15 21:00:00 - Sıcaklık: 24.33°C - Hava Durumu: Açık
# Tarih: 2024-08-16 00:00:00 - Sıcaklık: 23.74°C - Hava Durumu: Açık
# Tarih: 2024-08-16 03:00:00 - Sıcaklık: 23.42°C - Hava Durumu: Açık
# Tarih: 2024-08-16 06:00:00 - Sıcaklık: 26°C - Hava Durumu: Açık
# Tarih: 2024-08-16 09:00:00 - Sıcaklık: 28.6°C - Hava Durumu: Açık
# Tarih: 2024-08-16 12:00:00 - Sıcaklık: 29.11°C - Hava Durumu: Açık
# Tarih: 2024-08-16 15:00:00 - Sıcaklık: 27.59°C - Hava Durumu: Açık
# Tarih: 2024-08-16 18:00:00 - Sıcaklık: 25.52°C - Hava Durumu: Açık
# Tarih: 2024-08-16 21:00:00 - Sıcaklık: 24.81°C - Hava Durumu: Açık
# Tarih: 2024-08-17 00:00:00 - Sıcaklık: 24.38°C - Hava Durumu: Açık
# Tarih: 2024-08-17 03:00:00 - Sıcaklık: 24.08°C - Hava Durumu: Açık
# Tarih: 2024-08-17 06:00:00 - Sıcaklık: 26.46°C - Hava Durumu: Açık
# Tarih: 2024-08-17 09:00:00 - Sıcaklık: 28.84°C - Hava Durumu: Açık
# Tarih: 2024-08-17 12:00:00 - Sıcaklık: 28.98°C - Hava Durumu: Açık
# Tarih: 2024-08-17 15:00:00 - Sıcaklık: 27.45°C - Hava Durumu: Açık
# Tarih: 2024-08-17 18:00:00 - Sıcaklık: 25.39°C - Hava Durumu: Açık
# Tarih: 2024-08-17 21:00:00 - Sıcaklık: 24.82°C - Hava Durumu: Açık
# Tarih: 2024-08-18 00:00:00 - Sıcaklık: 24.36°C - Hava Durumu: Açık
# Tarih: 2024-08-18 03:00:00 - Sıcaklık: 24.14°C - Hava Durumu: Açık
# Tarih: 2024-08-18 06:00:00 - Sıcaklık: 26.11°C - Hava Durumu: Açık
# Tarih: 2024-08-18 09:00:00 - Sıcaklık: 29.13°C - Hava Durumu: Açık
# Tarih: 2024-08-18 12:00:00 - Sıcaklık: 29.84°C - Hava Durumu: Açık
# Tarih: 2024-08-18 15:00:00 - Sıcaklık: 28.13°C - Hava Durumu: Açık
# Tarih: 2024-08-18 18:00:00 - Sıcaklık: 25.47°C - Hava Durumu: Açık
# Tarih: 2024-08-18 21:00:00 - Sıcaklık: 24.72°C - Hava Durumu: Açık
# Tarih: 2024-08-19 00:00:00 - Sıcaklık: 23.83°C - Hava Durumu: Açık
# Tarih: 2024-08-19 03:00:00 - Sıcaklık: 23.25°C - Hava Durumu: Açık
# Tarih: 2024-08-19 06:00:00 - Sıcaklık: 25.79°C - Hava Durumu: Açık
# Tarih: 2024-08-19 09:00:00 - Sıcaklık: 29.19°C - Hava Durumu: Açık
# Tarih: 2024-08-19 12:00:00 - Sıcaklık: 31.54°C - Hava Durumu: Açık
# Tarih: 2024-08-19 15:00:00 - Sıcaklık: 28.62°C - Hava Durumu: Açık
# Tarih: 2024-08-19 18:00:00 - Sıcaklık: 25.56°C - Hava Durumu: Açık
# Programdan çıkılıyor...
