# %%
import os
import requests

# API anahtarınızı doğrudan buraya girin
apiKey = 'dcbe55c1e3134568a5824acb8fc1ca1a'  # Buraya kendi API anahtarınızı ekleyin
baseUrl = "http://api.openweathermap.org/data/2.5/"

class HavaDurumuAlici:
    def __init__(self, apiKey):
        self.apiKey = apiKey

    def havaDurumuGetir(self, sehir):
        try:
            url = f"{baseUrl}weather?q={sehir}&appid={self.apiKey}&units=metric&lang=tr"
            cevap = requests.get(url)
            veri = cevap.json()

            if cevap.status_code == 200:
                return veri
            else:
                print(f"{sehir} şehri bulunamadı veya başka bir hata oluştu. Durum kodu: {cevap.status_code}.")
                return None
        except Exception as e:
            print(f"Hata: {e}")
            return None

    def tahminGetir(self, sehir):
        try:
            url = f"{baseUrl}forecast?q={sehir}&appid={self.apiKey}&units=metric&lang=tr"
            cevap = requests.get(url)
            veri = cevap.json()

            if cevap.status_code == 200:
                return veri
            else:
                print(f"{sehir} şehri bulunamadı veya başka bir hata oluştu. Durum kodu: {cevap.status_code}.")
                return None
        except Exception as e:
            print(f"Hata: {e}")
            return None

    def havaDurumuBilgileriniYazdir(self, sehir):
        havaDurumuVerisi = self.havaDurumuGetir(sehir)

        if havaDurumuVerisi:
            print(f"\n{sehir} için hava durumu:")
            print(f"Sıcaklık: {havaDurumuVerisi['main']['temp']}°C")
            print(f"Hissedilen Sıcaklık: {havaDurumuVerisi['main']['feels_like']}°C")
            print(f"Nem: {havaDurumuVerisi['main']['humidity']}%")
            print(f"Rüzgar Hızı: {havaDurumuVerisi['wind']['speed']} m/s")
            print(f"Rüzgar Yönü: {havaDurumuVerisi['wind']['deg']}°")

            if 'weather' in havaDurumuVerisi and len(havaDurumuVerisi['weather']) > 0:
                aciklama = havaDurumuVerisi['weather'][0]['description']
                print(f"Hava Durumu: {aciklama.capitalize()}")
            else:
                print("Hava durumu bilgisi bulunamadı.")
    
    def farkliZamanDilimlerindeHavaDurumu(self, sehir):
        tahminVerisi = self.tahminGetir(sehir)
        if tahminVerisi:
            print(f"\n{sehir} için farklı zaman dilimlerinde hava durumu:")
            for giris in tahminVerisi['list']:
                tarih = giris['dt_txt']
                sicaklik = giris['main']['temp']
                aciklama = giris['weather'][0]['description']
                print(f"Tarih: {tarih} - Sıcaklık: {sicaklik}°C - Hava Durumu: {aciklama.capitalize()}")

def ana():
    print("Hava Durumu Uygulamasına Hoşgeldiniz!")
    print("Bu program, girdiğiniz şehir için hava durumu bilgilerini, farklı zaman dilimlerinde hava durumunu ve hava durumu uyarılarını sağlar.")
    print("Programdan çıkmak için 'çık' yazabilirsiniz.\n")
    
    alici = HavaDurumuAlici(apiKey)
    
    while True:
        sehir = input("Şehir adını girin (çıkmak için 'çık' yazın): ").strip()
        if sehir.lower() == 'çık':
            print("Programdan çıkılıyor...")
            break
        if not sehir:
            print("Geçersiz şehir adı, lütfen tekrar deneyin.")
            continue

        alici.havaDurumuBilgileriniYazdir(sehir)
        alici.farkliZamanDilimlerindeHavaDurumu(sehir)

if __name__ == "__main__":
    ana()
# Out:
# Hava Durumu Uygulamasına Hoşgeldiniz!
# Bu program, girdiğiniz şehir için hava durumu bilgilerini, farklı zaman dilimlerinde hava durumunu ve hava durumu uyarılarını sağlar.
# Programdan çıkmak için 'çık' yazabilirsiniz.
#
#
# Ankara için hava durumu:
# Sıcaklık: 26.23°C
# Hissedilen Sıcaklık: 26.23°C
# Nem: 26%
# Rüzgar Hızı: 2.68 m/s
# Rüzgar Yönü: 45°
# Hava Durumu: Açık
#
# Ankara için farklı zaman dilimlerinde hava durumu:
# Tarih: 2024-08-16 12:00:00 - Sıcaklık: 26.23°C - Hava Durumu: Açık
# Tarih: 2024-08-16 15:00:00 - Sıcaklık: 27.15°C - Hava Durumu: Açık
# Tarih: 2024-08-16 18:00:00 - Sıcaklık: 24.38°C - Hava Durumu: Açık
# Tarih: 2024-08-16 21:00:00 - Sıcaklık: 19.75°C - Hava Durumu: Açık
# Tarih: 2024-08-17 00:00:00 - Sıcaklık: 16.99°C - Hava Durumu: Açık
# Tarih: 2024-08-17 03:00:00 - Sıcaklık: 14.91°C - Hava Durumu: Açık
# Tarih: 2024-08-17 06:00:00 - Sıcaklık: 19.81°C - Hava Durumu: Açık
# Tarih: 2024-08-17 09:00:00 - Sıcaklık: 25.77°C - Hava Durumu: Açık
# Tarih: 2024-08-17 12:00:00 - Sıcaklık: 28.42°C - Hava Durumu: Açık
# Tarih: 2024-08-17 15:00:00 - Sıcaklık: 28.09°C - Hava Durumu: Açık
# Tarih: 2024-08-17 18:00:00 - Sıcaklık: 23.3°C - Hava Durumu: Açık
# Tarih: 2024-08-17 21:00:00 - Sıcaklık: 20.03°C - Hava Durumu: Açık
# Tarih: 2024-08-18 00:00:00 - Sıcaklık: 17.63°C - Hava Durumu: Açık
# Tarih: 2024-08-18 03:00:00 - Sıcaklık: 16.01°C - Hava Durumu: Açık
# Tarih: 2024-08-18 06:00:00 - Sıcaklık: 22.19°C - Hava Durumu: Açık
# Tarih: 2024-08-18 09:00:00 - Sıcaklık: 28.21°C - Hava Durumu: Açık
# Tarih: 2024-08-18 12:00:00 - Sıcaklık: 31.45°C - Hava Durumu: Açık
# Tarih: 2024-08-18 15:00:00 - Sıcaklık: 31.92°C - Hava Durumu: Açık
# Tarih: 2024-08-18 18:00:00 - Sıcaklık: 26.39°C - Hava Durumu: Açık
# Tarih: 2024-08-18 21:00:00 - Sıcaklık: 23.59°C - Hava Durumu: Açık
# Tarih: 2024-08-19 00:00:00 - Sıcaklık: 21.72°C - Hava Durumu: Açık
# Tarih: 2024-08-19 03:00:00 - Sıcaklık: 20.44°C - Hava Durumu: Açık
# Tarih: 2024-08-19 06:00:00 - Sıcaklık: 28.36°C - Hava Durumu: Açık
# Tarih: 2024-08-19 09:00:00 - Sıcaklık: 32.9°C - Hava Durumu: Açık
# Tarih: 2024-08-19 12:00:00 - Sıcaklık: 35.14°C - Hava Durumu: Açık
# Tarih: 2024-08-19 15:00:00 - Sıcaklık: 34.15°C - Hava Durumu: Açık
# Tarih: 2024-08-19 18:00:00 - Sıcaklık: 27.97°C - Hava Durumu: Açık
# Tarih: 2024-08-19 21:00:00 - Sıcaklık: 25.02°C - Hava Durumu: Açık
# Tarih: 2024-08-20 00:00:00 - Sıcaklık: 23.05°C - Hava Durumu: Açık
# Tarih: 2024-08-20 03:00:00 - Sıcaklık: 21.19°C - Hava Durumu: Açık
# Tarih: 2024-08-20 06:00:00 - Sıcaklık: 28.1°C - Hava Durumu: Açık
# Tarih: 2024-08-20 09:00:00 - Sıcaklık: 33.76°C - Hava Durumu: Açık
# Tarih: 2024-08-20 12:00:00 - Sıcaklık: 35.92°C - Hava Durumu: Açık
# Tarih: 2024-08-20 15:00:00 - Sıcaklık: 35.63°C - Hava Durumu: Açık
# Tarih: 2024-08-20 18:00:00 - Sıcaklık: 29.53°C - Hava Durumu: Açık
# Tarih: 2024-08-20 21:00:00 - Sıcaklık: 26.83°C - Hava Durumu: Açık
# Tarih: 2024-08-21 00:00:00 - Sıcaklık: 24.33°C - Hava Durumu: Açık
# Tarih: 2024-08-21 03:00:00 - Sıcaklık: 22.57°C - Hava Durumu: Açık
# Tarih: 2024-08-21 06:00:00 - Sıcaklık: 29.41°C - Hava Durumu: Açık
# Tarih: 2024-08-21 09:00:00 - Sıcaklık: 35.19°C - Hava Durumu: Açık
# Programdan çıkılıyor...
